# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit
import tensorflow as tf
from tensorflow.keras.optimizers import SGD,RMSprop,Adam
from tensorflow import keras
from sklearn.cluster import k_means
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,MinMaxScaler
import os
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import losses
from tensorflow.keras import metrics

# %%
dataframe_train = pd.read_csv("Dataset2/train.csv",)
dataframe_test=pd.read_csv("Dataset2/test.csv",)

# %%
dataframe_train["DEFCON_Level"].value_counts()
# Out:
# 2    4270
# 3    3910
# 4    1212
# 1     498
# 5     110
# Name: DEFCON_Level, dtype: int64

# %%
#dataframe_train.where(dataframe_train["DEFCON_Level"]==5,inplace=True)

# %%
dataframe_train
# Out:
#       Allied_Nations  Diplomatic_Meetings_Set  Percent_Of_Forces_Mobilized  \
# 0                 16                        1                         0.67
# 1                  8                        1                         0.11
# 2                  9                        1                         0.49
# 3                  7                        0                         0.30
# 4                  8                        1                         0.12
# ...              ...                      ...                          ...
# 9995              11                        1                         0.49
# 9996              10                        0                         0.52
# 9997               7                        1                         0.13
# 9998              10                        1                         0.42
# 9999               8                        1                         0.24
#
#       Hostile_Nations  Active_Threats  Inactive_Threats  Citizen_Fear_Index  \
# 0                   3             6.0              25.0            0.787812
# 1                   2            38.0              48.0            0.419236
# 2                   3            32.0              69.0            0.582232
# 3                   2            31.0              52.0            0.589574
# 4                   5            13.0              42.0            0.552863
# ...               ...             ...               ...                 ...
# 9995                5             5.0              13.0            0.919971
# 9996                2            14.0              28.0            0.433921
# 9997                2            25.0              42.0            0.470631
# 9998                2            21.0              84.0            0.662996
# 9999                2            15.0             105.0            0.423642
#
#       Closest_Threat_Distance(km)  Aircraft_Carriers_Responding  \
# 0                          324.36                             1
# 1                          359.34                             0
# 2                          332.84                             1
# 3                          358.28                             1
# 4                          364.64                             0
# ...                           ...                           ...
# 9995                       329.66                             1
# 9996                       348.74                             1
# 9997                       366.76                             1
# 9998                       348.74                             1
# 9999                       355.10                             1
#
#       Troops_Mobilized(thousands)  DEFCON_Level     ID
# 0                        862400.0             3   7570
# 1                        959200.0             4  12128
# 2                        836000.0             3   2181
# 3                        924000.0             3   5946
# 4                        968000.0             2   9054
# ...                           ...           ...    ...
# 9995                    1029600.0             4  11493
# 9996                    1047200.0             3    305
# 9997                     941600.0             3    612
# 9998                     836000.0             2   4963
# 9999                     862400.0             2   9387
#
# [10000 rows x 12 columns]

# %%
dataframe_train["Allied_Nations"]=dataframe_train["Allied_Nations"].astype(np.float16)
dataframe_train["Diplomatic_Meetings_Set"]=dataframe_train["Diplomatic_Meetings_Set"].astype(np.float16)
dataframe_train["Hostile_Nations"]=dataframe_train["Hostile_Nations"].astype(np.float16)
dataframe_train["Aircraft_Carriers_Responding"]=dataframe_train["Aircraft_Carriers_Responding"].astype(np.float16)

# %%
# del dataframe_train["Adverse_Weather_Metric"]
# del dataframe_train["Max_Elevation"]
dataframe_train
# Out:
#       Allied_Nations  Diplomatic_Meetings_Set  Percent_Of_Forces_Mobilized  \
# 0               16.0                      1.0                         0.67
# 1                8.0                      1.0                         0.11
# 2                9.0                      1.0                         0.49
# 3                7.0                      0.0                         0.30
# 4                8.0                      1.0                         0.12
# ...              ...                      ...                          ...
# 9995            11.0                      1.0                         0.49
# 9996            10.0                      0.0                         0.52
# 9997             7.0                      1.0                         0.13
# 9998            10.0                      1.0                         0.42
# 9999             8.0                      1.0                         0.24
#
#       Hostile_Nations  Active_Threats  Inactive_Threats  Citizen_Fear_Index  \
# 0                 3.0             6.0              25.0            0.787812
# 1                 2.0            38.0              48.0            0.419236
# 2                 3.0            32.0              69.0            0.582232
# 3                 2.0            31.0              52.0            0.589574
# 4                 5.0            13.0              42.0            0.552863
# ...               ...             ...               ...                 ...
# 9995              5.0             5.0              13.0            0.919971
# 9996              2.0            14.0              28.0            0.433921
# 9997              2.0            25.0              42.0            0.470631
# 9998              2.0            21.0              84.0            0.662996
# 9999              2.0            15.0             105.0            0.423642
#
#       Closest_Threat_Distance(km)  Aircraft_Carriers_Responding  \
# 0                          324.36                           1.0
# 1                          359.34                           0.0
# 2                          332.84                           1.0
# 3                          358.28                           1.0
# 4                          364.64                           0.0
# ...                           ...                           ...
# 9995                       329.66                           1.0
# 9996                       348.74                           1.0
# 9997                       366.76                           1.0
# 9998                       348.74                           1.0
# 9999                       355.10                           1.0
#
#       Troops_Mobilized(thousands)  DEFCON_Level     ID
# 0                        862400.0             3   7570
# 1                        959200.0             4  12128
# 2                        836000.0             3   2181
# 3                        924000.0             3   5946
# 4                        968000.0             2   9054
# ...                           ...           ...    ...
# 9995                    1029600.0             4  11493
# 9996                    1047200.0             3    305
# 9997                     941600.0             3    612
# 9998                     836000.0             2   4963
# 9999                     862400.0             2   9387
#
# [10000 rows x 12 columns]

# %%
train_data=dataframe_train.iloc[:,:10]

# %%
train_data
# Out:
#       Allied_Nations  Diplomatic_Meetings_Set  Percent_Of_Forces_Mobilized  \
# 0               16.0                      1.0                         0.67
# 1                8.0                      1.0                         0.11
# 2                9.0                      1.0                         0.49
# 3                7.0                      0.0                         0.30
# 4                8.0                      1.0                         0.12
# ...              ...                      ...                          ...
# 9995            11.0                      1.0                         0.49
# 9996            10.0                      0.0                         0.52
# 9997             7.0                      1.0                         0.13
# 9998            10.0                      1.0                         0.42
# 9999             8.0                      1.0                         0.24
#
#       Hostile_Nations  Active_Threats  Inactive_Threats  Citizen_Fear_Index  \
# 0                 3.0             6.0              25.0            0.787812
# 1                 2.0            38.0              48.0            0.419236
# 2                 3.0            32.0              69.0            0.582232
# 3                 2.0            31.0              52.0            0.589574
# 4                 5.0            13.0              42.0            0.552863
# ...               ...             ...               ...                 ...
# 9995              5.0             5.0              13.0            0.919971
# 9996              2.0            14.0              28.0            0.433921
# 9997              2.0            25.0              42.0            0.470631
# 9998              2.0            21.0              84.0            0.662996
# 9999              2.0            15.0             105.0            0.423642
#
#       Closest_Threat_Distance(km)  Aircraft_Carriers_Responding  \
# 0                          324.36                           1.0
# 1                          359.34                           0.0
# 2                          332.84                           1.0
# 3                          358.28                           1.0
# 4                          364.64                           0.0
# ...                           ...                           ...
# 9995                       329.66                           1.0
# 9996                       348.74                           1.0
# 9997                       366.76                           1.0
# 9998                       348.74                           1.0
# 9999                       355.10                           1.0
#
#       Troops_Mobilized(thousands)
# 0                        862400.0
# 1                        959200.0
# 2                        836000.0
# 3                        924000.0
# 4                        968000.0
# ...                           ...
# 9995                    1029600.0
# 9996                    1047200.0
# 9997                     941600.0
# 9998                     836000.0
# 9999                     862400.0
#
# [10000 rows x 10 columns]

# %%
# mean = train_data.mean(axis=0)
# train_data -= mean
# std = train_data.std(axis=0)
# train_data /= std
scaler=MinMaxScaler()
train_data = scaler.fit_transform(train_data)

# %%
train_data
# Out:
# array([[1.        , 0.5       , 0.67      , ..., 0.2519685 , 0.5       ,
#         0.21538462],
#        [0.27272727, 0.5       , 0.11      , ..., 0.51181102, 0.        ,
#         0.38461538],
#        [0.36363636, 0.5       , 0.49      , ..., 0.31496063, 0.5       ,
#         0.16923077],
#        ...,
#        [0.18181818, 0.5       , 0.13      , ..., 0.56692913, 0.5       ,
#         0.35384615],
#        [0.45454545, 0.5       , 0.42      , ..., 0.43307087, 0.5       ,
#         0.16923077],
#        [0.27272727, 0.5       , 0.24      , ..., 0.48031496, 0.5       ,
#         0.21538462]])

# %%
labels=dataframe_train.iloc[:,10]

# %%
encoded=LabelEncoder()
encoded.fit(labels)
labels_encoded=encoded.transform(labels)
labels_encoded
# Out:
# array([2, 3, 2, ..., 2, 1, 1])

# %%
np.unique(labels_encoded)
# Out:
# array([0, 1, 2, 3, 4])

# %%
def build_model():
    model=Sequential()
    model.add(Dense(128,activation="relu",input_shape=(train_data.shape[1],)))
    model.add(Dense(128,activation='relu'))
    model.add(Dense(64,activation='relu'))
    model.add(Dense(5,activation='softmax'))
    
    
    return model

# %%
trainx,testx,trainy,testy=train_test_split(train_data,labels_encoded,test_size=0.25,random_state=42)

# %%
model=build_model()
model.compile(loss='sparse_categorical_crossentropy',optimizer=Adam(lr=1e-4),metrics=['accuracy'])

model.fit(trainx,trainy,epochs=50,batch_size=1,validation_data=(testx, testy),verbose=1)
# Out:
# Train on 7500 samples, validate on 2500 samples
# Epoch 1/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 1.0902 - accuracy: 0.5355 - val_loss: 1.0443 - val_accuracy: 0.5300
# Epoch 2/32
# 7500/7500 [==============================] - 15s 2ms/sample - loss: 1.0215 - accuracy: 0.5492 - val_loss: 1.0192 - val_accuracy: 0.5504
# Epoch 3/32
# 7500/7500 [==============================] - 15s 2ms/sample - loss: 1.0097 - accuracy: 0.5535 - val_loss: 1.0039 - val_accuracy: 0.5544
# Epoch 4/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 1.0032 - accuracy: 0.5572 - val_loss: 1.0055 - val_accuracy: 0.5568
# Epoch 5/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9983 - accuracy: 0.5600 - val_loss: 0.9952 - val_accuracy: 0.5580
# Epoch 6/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9940 - accuracy: 0.5589 - val_loss: 1.0053 - val_accuracy: 0.5592
# Epoch 7/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9891 - accuracy: 0.5584 - val_loss: 0.9942 - val_accuracy: 0.5572
# Epoch 8/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9862 - accuracy: 0.5576 - val_loss: 1.0289 - val_accuracy: 0.5192
# Epoch 9/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9826 - accuracy: 0.5655 - val_loss: 0.9944 - val_accuracy: 0.5620
# Epoch 10/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9788 - accuracy: 0.5617 - val_loss: 0.9903 - val_accuracy: 0.5560
# Epoch 11/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9769 - accuracy: 0.5665 - val_loss: 1.0095 - val_accuracy: 0.5568
# Epoch 12/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9733 - accuracy: 0.5649 - val_loss: 0.9888 - val_accuracy: 0.5528
# Epoch 13/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9709 - accuracy: 0.5648 - val_loss: 0.9836 - val_accuracy: 0.5592
# Epoch 14/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9687 - accuracy: 0.5676 - val_loss: 0.9889 - val_accuracy: 0.5612
# Epoch 15/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9680 - accuracy: 0.5680 - val_loss: 0.9780 - val_accuracy: 0.5680
# Epoch 16/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9643 - accuracy: 0.5716 - val_loss: 0.9792 - val_accuracy: 0.5672
# Epoch 17/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9638 - accuracy: 0.5675 - val_loss: 0.9761 - val_accuracy: 0.5684
# Epoch 18/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9594 - accuracy: 0.5700 - val_loss: 0.9838 - val_accuracy: 0.5640
# Epoch 19/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9583 - accuracy: 0.5759 - val_loss: 0.9729 - val_accuracy: 0.5704
# Epoch 20/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9561 - accuracy: 0.5737 - val_loss: 0.9786 - val_accuracy: 0.5624
# Epoch 21/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9543 - accuracy: 0.5765 - val_loss: 0.9983 - val_accuracy: 0.5328
# Epoch 22/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9514 - accuracy: 0.5755 - val_loss: 0.9729 - val_accuracy: 0.5628
# Epoch 23/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9492 - accuracy: 0.5745 - val_loss: 0.9827 - val_accuracy: 0.5604
# Epoch 24/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9484 - accuracy: 0.5747 - val_loss: 0.9753 - val_accuracy: 0.5644
# Epoch 25/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9465 - accuracy: 0.5748 - val_loss: 0.9778 - val_accuracy: 0.5560
# Epoch 26/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9449 - accuracy: 0.5760 - val_loss: 0.9781 - val_accuracy: 0.5692
# Epoch 27/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9417 - accuracy: 0.5783 - val_loss: 0.9699 - val_accuracy: 0.5720
# Epoch 28/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9401 - accuracy: 0.5820 - val_loss: 0.9705 - val_accuracy: 0.5672
# Epoch 29/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9383 - accuracy: 0.5808 - val_loss: 0.9813 - val_accuracy: 0.5580
# Epoch 30/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9373 - accuracy: 0.5780 - val_loss: 0.9727 - val_accuracy: 0.5592
# Epoch 31/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9342 - accuracy: 0.5848 - val_loss: 0.9793 - val_accuracy: 0.5488
# Epoch 32/32
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.9341 - accuracy: 0.5853 - val_loss: 0.9803 - val_accuracy: 0.5536

# %%
model.save("model.Deficon")
# Out:
# WARNING:tensorflow:From /home/fahad/.local/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: model.Deficon/assets

# %%
from tensorflow.keras import models

# %%
model=models.load_model("model.Deficon")

# %%
dataframe_test["Allied_Nations"]=dataframe_test["Allied_Nations"].astype(np.float16)
dataframe_test["Diplomatic_Meetings_Set"]=dataframe_test["Diplomatic_Meetings_Set"].astype(np.float16)
dataframe_test["Hostile_Nations"]=dataframe_test["Hostile_Nations"].astype(np.float16)
dataframe_test["Aircraft_Carriers_Responding"]=dataframe_test["Aircraft_Carriers_Responding"].astype(np.float16)

# %%
test_data=dataframe_test.iloc[:,:-1]

# %%
test_data
# Out:
#       Allied_Nations  Diplomatic_Meetings_Set  Percent_Of_Forces_Mobilized  \
# 0                8.0                      0.0                         0.52
# 1                9.0                      0.0                         0.44
# 2                8.0                      0.0                         0.44
# 3               10.0                      0.0                         0.39
# 4                9.0                      0.0                         0.44
# ...              ...                      ...                          ...
# 2495             8.0                      1.0                         0.27
# 2496             7.0                      1.0                         0.03
# 2497            10.0                      1.0                         0.25
# 2498            10.0                      0.0                         0.42
# 2499            10.0                      1.0                         0.28
#
#       Hostile_Nations  Active_Threats  Inactive_Threats  Citizen_Fear_Index  \
# 0                 2.0            19.0              52.0            0.376652
# 1                 2.0             6.0              12.0            0.254772
# 2                 3.0             7.0              18.0            0.472100
# 3                 2.0             3.0              13.0            0.478708
# 4                 2.0             6.0              14.0            0.561674
# ...               ...             ...               ...                 ...
# 2495              3.0             5.0              77.0            0.552863
# 2496              3.0             7.0              15.0            0.588106
# 2497              3.0            33.0             151.0            0.626285
# 2498              2.0             5.0              12.0            0.507342
# 2499              3.0            22.0              99.0            0.582232
#
#       Closest_Threat_Distance(km)  Aircraft_Carriers_Responding  \
# 0                          319.06                           1.0
# 1                          351.92                           1.0
# 2                          349.80                           1.0
# 3                          343.44                           1.0
# 4                          346.62                           1.0
# ...                           ...                           ...
# 2495                       338.14                           1.0
# 2496                       363.58                           1.0
# 2497                       334.96                           1.0
# 2498                       336.02                           0.0
# 2499                       351.92                           1.0
#
#       Troops_Mobilized(thousands)
# 0                        976800.0
# 1                       1082400.0
# 2                        924000.0
# 3                       1003200.0
# 4                        924000.0
# ...                           ...
# 2495                     827200.0
# 2496                     827200.0
# 2497                     809600.0
# 2498                     950400.0
# 2499                     827200.0
#
# [2500 rows x 10 columns]

# %%
mean = test_data.mean(axis=0)
test_data -= mean
std = test_data.std(axis=0)
test_data /= std

# %%
label_predict=model.predict_classes(test_data)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
result_encoded=encoded.inverse_transform(label_predict)

# %%
result_encoded
# Out:
# array([4, 3, 3, ..., 2, 3, 2])

# %%
ResultCSV=dataframe_test.copy()

# %%
ResultCSV["DEFCON_Level"]=result_encoded

# %%
ResultCSV
# Out:
#       Allied_Nations  Diplomatic_Meetings_Set  Percent_Of_Forces_Mobilized  \
# 0                8.0                      0.0                         0.52
# 1                9.0                      0.0                         0.44
# 2                8.0                      0.0                         0.44
# 3               10.0                      0.0                         0.39
# 4                9.0                      0.0                         0.44
# ...              ...                      ...                          ...
# 2495             8.0                      1.0                         0.27
# 2496             7.0                      1.0                         0.03
# 2497            10.0                      1.0                         0.25
# 2498            10.0                      0.0                         0.42
# 2499            10.0                      1.0                         0.28
#
#       Hostile_Nations  Active_Threats  Inactive_Threats  Citizen_Fear_Index  \
# 0                 2.0            19.0              52.0            0.376652
# 1                 2.0             6.0              12.0            0.254772
# 2                 3.0             7.0              18.0            0.472100
# 3                 2.0             3.0              13.0            0.478708
# 4                 2.0             6.0              14.0            0.561674
# ...               ...             ...               ...                 ...
# 2495              3.0             5.0              77.0            0.552863
# 2496              3.0             7.0              15.0            0.588106
# 2497              3.0            33.0             151.0            0.626285
# 2498              2.0             5.0              12.0            0.507342
# 2499              3.0            22.0              99.0            0.582232
#
#       Closest_Threat_Distance(km)  Aircraft_Carriers_Responding  \
# 0                          319.06                           1.0
# 1                          351.92                           1.0
# 2                          349.80                           1.0
# 3                          343.44                           1.0
# 4                          346.62                           1.0
# ...                           ...                           ...
# 2495                       338.14                           1.0
# 2496                       363.58                           1.0
# 2497                       334.96                           1.0
# 2498                       336.02                           0.0
# 2499                       351.92                           1.0
#
#       Troops_Mobilized(thousands)     ID  DEFCON_Level
# 0                        976800.0      1             4
# 1                       1082400.0     10             3
# 2                        924000.0     14             3
# 3                       1003200.0     17             3
# 4                        924000.0     21             2
# ...                           ...    ...           ...
# 2495                     827200.0  12484             2
# 2496                     827200.0  12487             2
# 2497                     809600.0  12488             2
# 2498                     950400.0  12491             3
# 2499                     827200.0  12493             2
#
# [2500 rows x 12 columns]

# %%
ResultCSV.loc[:,"ID":"DEFCON_Level"].to_csv(r"Result.csv",index=False)

# %%
def build_models():
    model=Sequential()
    model.add(Dense(128,activation="relu",input_shape=(train_data.shape[1],)))
    model.add(Dense(128,activation='relu'))
    model.add(Dense(16,activation='relu'))
    
    model.add(Dense(8,activation='relu'))
    model.add(Dense(4,activation='softmax'))
    
    
    return model

# %%
model=build_models()
model.compile(loss='sparse_categorical_crossentropy',optimizer=Adam(lr=1e-4),metrics=['accuracy'])

model.fit(trainx,trainy,epochs=20,batch_size=1,validation_data=(testx, testy),verbose=1)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 7500 samples, validate on 2500 samples
# Epoch 1/20
# 7500/7500 [==============================] - 15s 2ms/sample - loss: 1.0111 - accuracy: 0.6015 - val_loss: 0.6669 - val_accuracy: 0.7964
# Epoch 2/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.4989 - accuracy: 0.8399 - val_loss: 0.4255 - val_accuracy: 0.8600
# Epoch 3/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.3519 - accuracy: 0.8785 - val_loss: 0.3604 - val_accuracy: 0.8640
# Epoch 4/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.2976 - accuracy: 0.8901 - val_loss: 0.3160 - val_accuracy: 0.8816
# Epoch 5/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.2626 - accuracy: 0.8963 - val_loss: 0.2890 - val_accuracy: 0.8972
# Epoch 6/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.2402 - accuracy: 0.9133 - val_loss: 0.2722 - val_accuracy: 0.9156
# Epoch 7/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.2209 - accuracy: 0.9303 - val_loss: 0.2612 - val_accuracy: 0.9168
# Epoch 8/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.2054 - accuracy: 0.9365 - val_loss: 0.2536 - val_accuracy: 0.9252
# Epoch 9/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1934 - accuracy: 0.9403 - val_loss: 0.2435 - val_accuracy: 0.9212
# Epoch 10/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1850 - accuracy: 0.9413 - val_loss: 0.2489 - val_accuracy: 0.9200
# Epoch 11/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1792 - accuracy: 0.9412 - val_loss: 0.2339 - val_accuracy: 0.9312
# Epoch 12/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1741 - accuracy: 0.9441 - val_loss: 0.2251 - val_accuracy: 0.9352
# Epoch 13/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1679 - accuracy: 0.9452 - val_loss: 0.2276 - val_accuracy: 0.9304
# Epoch 14/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1622 - accuracy: 0.9481 - val_loss: 0.2525 - val_accuracy: 0.9252
# Epoch 15/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1598 - accuracy: 0.9493 - val_loss: 0.2298 - val_accuracy: 0.9300
# Epoch 16/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1531 - accuracy: 0.9493 - val_loss: 0.2308 - val_accuracy: 0.9300
# Epoch 17/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1530 - accuracy: 0.9505 - val_loss: 0.2329 - val_accuracy: 0.9320
# Epoch 18/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1497 - accuracy: 0.9520 - val_loss: 0.2282 - val_accuracy: 0.9304
# Epoch 19/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1451 - accuracy: 0.9515 - val_loss: 0.2275 - val_accuracy: 0.9312
# Epoch 20/20
# 7500/7500 [==============================] - 16s 2ms/sample - loss: 0.1421 - accuracy: 0.9539 - val_loss: 0.2291 - val_accuracy: 0.9320
